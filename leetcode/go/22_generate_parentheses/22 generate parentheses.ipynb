// %%
// 22. Generate Parentheses

func generateParenthesis(n int) []string {
	result := []string{}
	
    return []string{""}
}

func main() {
	n := 3
	result := generateParenthesis(n)
	fmt.Println(result)
}
// Out:
// []
